# %%
class Human:
  def __init__(self,name,age):
    self.name=name
    self.age=age

  def printinfo(self):
    print(f"名前:{self.name}")
    print(f"年齢{self.age}")

person1=Human("侍太郎",25)
person1.printinfo()
# Out:
# 名前:侍太郎
# 年齢25
